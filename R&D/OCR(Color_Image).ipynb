# %%
import cv2
import pytesseract
from PIL import Image  
import os

# %%
# Color Filter to images

# %%
i = 1
path_image = os.chdir(r"D:\\R & D PROJECT\\Code File\\Samples\\Color Image")
for image in os.listdir(path_image):

    img = cv2.imread(image)
    img = cv2.cvtColor(img, cv.COLOR_RGB2GRAY)
    result=cv.adaptiveThreshold(img,255,cv2.ADAPTIVE_THRESH_GAUSSIAN_C,cv2.THRESH_BINARY,81,4)

    cv2.imwrite("D:\\R & D PROJECT\\Code File\\Samples\\Color Image\\Gray_Image\\GrayImage_"+str(i)+".jpg",result)
    i += 1
    
print("Done")

cv2.imshow("image",adaptive)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# Done

# %% [markdown]
# # Text Extraction

# %%
outfile = "D:\\R & D PROJECT\\Code File\\Samples\\Text Extracted file\\GrayImage_Text.txt"
f = open(outfile, "a+")

path_image = os.chdir("D:\\R & D PROJECT\\Code File\\Samples\\Gray_Image")
count =len(os.listdir(path_image))


for i in range(1, count+1): 
   
    filename = "D:\\R & D PROJECT\\Code File\\Samples\\Gray_Image\\GrayImage_"+str(i)+".jpg" 
    text = str(((pytesseract.image_to_string(Image.open(filename)))))  
    f.write("new line\n")    
   
    f.write(text) 
f.close()

# %% [markdown]
# # Text Cleaning

# %%
with open("D:\\R & D PROJECT\\Code File\\Samples\\Text Extracted file\\GrayImage_Text.txt", "r") as filename:
    lines = filename.readlines()

# %%
newline = "\n".join ([line.strip() for line in lines])

# %%
lst = []
for line in newline.split("new line"):
    if not line.strip():
            continue
    lst.append(line.lstrip().lower())
newlist = [new.replace("\n", " ") for new in lst]

# %%
len(newlist)
# Out:
# 41
